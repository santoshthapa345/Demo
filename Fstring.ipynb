# %%
name="Santosh Thapa"
age=22

# %%
print(f"My name is {name} and i am {age} years ols.")
# Out:
# My name is Santosh Thapa and i am 22 years ols.

# %%
print(f"My name is {name} and i am {age} years ols.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"My name is {name} and i am {age} years ols.")
#
# NameError: name 'name' is not defined
